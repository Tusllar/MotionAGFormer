# %%
import cv2
import os
import numpy as np

input_folder = r'C:\Users\tutra\Downloads\EWalk_Dataset\EWalk\Videos'      # Thư mục chứa video gốc
output_folder = r'C:\Users\tutra\Downloads\EWalk_Dataset\EWalk\New_Video'    # Thư mục lưu video đã resize

output_width, output_height = 720, 520

# Tạo thư mục đầu ra nếu chưa tồn tại
os.makedirs(output_folder, exist_ok=True)

# Duyệt từng file trong thư mục
for filename in os.listdir(input_folder):
    if filename.endswith(('.mp4', '.avi', '.mov', '.mkv')):  # Lọc file video
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, f"{filename}")
        print(input_path, output_path)
        video_name = input_path.split('/')[-1].split('.')[0]
        # output_dir = './demo/output/' + video_name + '/''
        print(video_name)

        # cap = cv2.VideoCapture(input_path)
        # fps = cap.get(cv2.CAP_PROP_FPS)
        # fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        # out = cv2.VideoWriter(output_path, fourcc, fps, (output_width, output_height))

        # print(f"🔄 Đang xử lý: {filename}")

        # while True:
        #     ret, frame = cap.read()
        #     if not ret:
        #         break

        #     h, w = frame.shape[:2]
        #     scale = min(output_width / w, output_height / h)
        #     new_w = int(w * scale)
        #     new_h = int(h * scale)

        #     resized_frame = cv2.resize(frame, (new_w, new_h))
        #     background = np.zeros((output_height, output_width, 3), dtype=np.uint8)

        #     x_offset = (output_width - new_w) // 2
        #     y_offset = (output_height - new_h) // 2
        #     background[y_offset:y_offset+new_h, x_offset:x_offset+new_w] = resized_frame

        #     out.write(background)

        # cap.release()
        # out.release()
        print(f"✅ Xong: {filename} ➜ {output_path}")

print("🎉 Hoàn tất xử lý toàn bộ video!")
# Out:
# C:\Users\tutra\Downloads\EWalk_Dataset\EWalk\Videos\VID_RGB_000.mp4 C:\Users\tutra\Downloads\EWalk_Dataset\EWalk\New_Video\VID_RGB_000.mp4
# C:\Users\tutra\Downloads\EWalk_Dataset\EWalk\Videos\VID_RGB_000
# ✅ Xong: VID_RGB_000.mp4 ➜ C:\Users\tutra\Downloads\EWalk_Dataset\EWalk\New_Video\VID_RGB_000.mp4
# C:\Users\tutra\Downloads\EWalk_Dataset\EWalk\Videos\VID_RGB_001.mp4 C:\Users\tutra\Downloads\EWalk_Dataset\EWalk\New_Video\VID_RGB_001.mp4
# C:\Users\tutra\Downloads\EWalk_Dataset\EWalk\Videos\VID_RGB_001
# ✅ Xong: VID_RGB_001.mp4 ➜ C:\Users\tutra\Downloads\EWalk_Dataset\EWalk\New_Video\VID_RGB_001.mp4
# C:\Users\tutra\Downloads\EWalk_Dataset\EWalk\Videos\VID_RGB_002.mp4 C:\Users\tutra\Downloads\EWalk_Dataset\EWalk\New_Video\VID_RGB_002.mp4
# C:\Users\tutra\Downloads\EWalk_Dataset\EWalk\Videos\VID_RGB_002
# ✅ Xong: VID_RGB_002.mp4 ➜ C:\Users\tutra\Downloads\EWalk_Dataset\EWalk\New_Video\VID_RGB_002.mp4
# ...
